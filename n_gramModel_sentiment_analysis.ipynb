# %%
# Loading requried libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use(style='seaborn')
import string

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re
from nltk.tokenize import word_tokenize
from nltk.util import ngrams

# Loading Dataset
df=pd.read_csv(r'data/all-data.csv',encoding = "ISO-8859-1")
df.head()
# Out:
# C:\Users\MOHAMMED USAMA\AppData\Local\Temp\ipykernel_17636\1520487198.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(style='seaborn')
#   Sentiment                                      News Headline
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...

# %%
# Checking the distribution
df['Sentiment'].value_counts()
# Out:
# Sentiment
# neutral     2879
# positive    1363
# negative     604
# Name: count, dtype: int64

# %%
df['Sentiment'] = df['Sentiment'].replace({'negative': 1, 'neutral': 2, 'positive': 3})

# %%
# Train Test split
train = df.sample(frac=0.7, random_state=42)
test = df.drop(train.index)

print(train.shape)
print(test.shape)
# Out:
# (3392, 2)
# (1454, 2)

# %% [markdown]
# For infomation and explanation about n grams refer the nlp.ipynb notebook

# %%
def process_text(news,n):
    """Process news function.
    Input:
        news: a string containing a news
    Output:
        news_clean: a list of words containing the processed news

    """
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    # remove stock market tickers like $GE
    news = re.sub(r'\$\w*', '', news)
    # remove old style renews text "RT"
    news = re.sub(r'^RT[\s]+', '', news)
    # remove hyperlinks    
    news = re.sub(r'https?://[^\s\n\r]+', '', news)
    # remove hashtags
    # only removing the hash # sign from the word
    news = re.sub(r'#', '', news)
    
    tokens  = word_tokenize(news)

    cleaned_tokens  = [token.lower() for token in tokens if token.lower() not in stopwords.words('english') and token not in string.punctuation]

    return list(ngrams(cleaned_tokens, n))

# %%
process_text("Create unigrams for each of the news records belonging to each of the three categories of sentiments",2)
# Out:
# [('create', 'unigrams'),
#  ('unigrams', 'news'),
#  ('news', 'records'),
#  ('records', 'belonging'),
#  ('belonging', 'three'),
#  ('three', 'categories'),
#  ('categories', 'sentiments')]

# %%
train['News_1gram'] = train['News Headline'].apply(lambda x: process_text(x, 1))
train['News_2gram'] = train['News Headline'].apply(lambda x: process_text(x, 2))
train['News_3gram'] = train['News Headline'].apply(lambda x: process_text(x, 3))

# %%
train.head()
# Out:
#       Sentiment                                      News Headline  \
# 3207          2  The company was supposed to deliver machinery ...
# 1684          2  UNC Charlotte would also deploy SSH Tectia Con...
# 1044          2  In 2009 , Lee & Man had a combined annual prod...
# 4145          2  `` That 's a very high figure on the European ...
# 1538          2  In Finland , the corresponding service is Alma...
#
#                                              News_1gram  \
# 3207  [(company,), (supposed,), (deliver,), (machine...
# 1684  [(unc,), (charlotte,), (would,), (also,), (dep...
# 1044  [(2009,), (lee,), (man,), (combined,), (annual...
# 4145  [(``,), ('s,), (high,), (figure,), (european,)...
# 1538  [(finland,), (corresponding,), (service,), (al...
#
#                                              News_2gram  \
# 3207  [(company, supposed), (supposed, deliver), (de...
# 1684  [(unc, charlotte), (charlotte, would), (would,...
# 1044  [(2009, lee), (lee, man), (man, combined), (co...
# 4145  [(``, 's), ('s, high), (high, figure), (figure...
# 1538  [(finland, corresponding), (corresponding, ser...
#
#                                              News_3gram
# 3207  [(company, supposed, deliver), (supposed, deli...
# 1684  [(unc, charlotte, would), (charlotte, would, a...
# 1044  [(2009, lee, man), (lee, man, combined), (man,...
# 4145  [(``, 's, high), ('s, high, figure), (high, fi...
# 1538  [(finland, corresponding, service), (correspon...

# %%
def build_freqs(news, ys):
    """Build frequencies.
    Input:
        news: a list of news
        ys: an m x 1 array with the sentiment label of each tweet
            (either 0 or 1)
    Output:
        freqs: a dictionary mapping each (word, sentiment) pair to its
        frequency
    """
    # Convert np array to list since zip needs an iterable.
    # The squeeze is necessary or the list ends up with one element.
    # Also note that this is just a NOP if ys is already a list.
    yslist = np.squeeze(ys).tolist()

    # Start with an empty dictionary and populate it by looping over all news
    # and over all processed words in each tweet.
    freqs = {}
    for y, new in zip(yslist, news):
        for word in new:
            pair = (word, y)
            if pair in freqs:
                freqs[pair] += 1
            else:
                freqs[pair] = 1

    return freqs

# %%
# For this project we will use only 3grams
freqs = build_freqs(train['News_3gram'], train['Sentiment'])

# %%
freqs
# Out:
# {(('company', 'supposed', 'deliver'), 2): 1,
#  (('supposed', 'deliver', 'machinery'), 2): 1,
#  (('deliver', 'machinery', 'veneer'), 2): 1,
#  (('machinery', 'veneer', 'mill'), 2): 1,
#  (('veneer', 'mill', 'tomsk'), 2): 1,
#  (('mill', 'tomsk', 'region'), 2): 1,
#  (('tomsk', 'region', 'russia'), 2): 1,
#  (('unc', 'charlotte', 'would'), 2): 1,
#  (('charlotte', 'would', 'also'), 2): 1,
#  (('would', 'also', 'deploy'), 2): 1,
#  (('also', 'deploy', 'ssh'), 2): 1,
#  (('deploy', 'ssh', 'tectia'), 2): 1,
#  (('ssh', 'tectia', 'connector'), 2): 1,
#  (('tectia', 'connector', 'enable'), 2): 1,
#  (('connector', 'enable', 'secure'), 2): 1,
#  (('enable', 'secure', 'application'), 2): 1,
#  (('secure', 'application', 'connectivity'), 2): 1,
#  (('2009', 'lee', 'man'), 2): 1,
#  (('lee', 'man', 'combined'), 2): 1,
#  (('man', 'combined', 'annual'), 2): 1,
#  (('combined', 'annual', 'production'), 2): 1,
#  (('annual', 'production', 'capacity'), 2): 3,
#  (('production', 'capacity', 'close'), 2): 1,
#  (('capacity', 'close', '4.5'), 2): 1,
#  (('close', '4.5', 'million'), 2): 1,
#  (('4.5', 'million', 'tonnes'), 2): 1,
#  (('million', 'tonnes', 'paper'), 2): 1,
#  (('tonnes', 'paper', '300,000'), 2): 1,
#  (('paper', '300,000', 'tonnes'), 2): 1,
#  (('300,000', 'tonnes', 'pulp'), 2): 1,
#  (('``', "'s", 'high'), 2): 1,
#  (("'s", 'high', 'figure'), 2): 1,
#  (('high', 'figure', 'european'), 2): 1,
#  (('figure', 'european', 'scale'), 2): 1,
#  (('european', 'scale', '``'), 2): 1,
#  (('scale', '``', 'noop'), 2): 1,
#  (('``', 'noop', 'said'), 2): 1,
#  (('noop', 'said', 'recalling'), 2): 1,
#  (('said', 'recalling', 'however'), 2): 1,
#  (('recalling', 'however', 'also'), 2): 1,
#  (('however', 'also', 'includes'), 2): 1,
#  (('also', 'includes', 'beer'), 2): 1,
#  (('includes', 'beer', 'bought'), 2): 1,
#  (('beer', 'bought', 'finnish'), 2): 1,
#  (('bought', 'finnish', 'tourists'), 2): 1,
#  (('finland', 'corresponding', 'service'), 2): 1,
#  (('corresponding', 'service', 'alma'), 2): 1,
#  (('service', 'alma', 'media'), 2): 1,
#  (('alma', 'media', "'s"), 2): 8,
#  (('media', "'s", 'etuovi.com'), 2): 1,
#  (("'s", 'etuovi.com', 'finland'), 2): 1,
#  (('etuovi.com', 'finland', "'s"), 2): 1,
#  (('finland', "'s", 'popular'), 2): 1,
#  (("'s", 'popular', 'best'), 2): 1,
#  (('popular', 'best', 'known'), 2): 1,
#  (('best', 'known', 'nationwide'), 2): 1,
#  (('known', 'nationwide', 'online'), 2): 1,
#  (('nationwide', 'online', 'service'), 2): 1,
#  (('online', 'service', 'home'), 2): 1,
#  (('service', 'home', 'property'), 2): 1,
#  (('home', 'property', 'sales'), 2): 1,
#  (('construction', 'scheduled', 'start'), 2): 1,
#  (('scheduled', 'start', 'april-june'), 2): 1,
#  (('start', 'april-june', '2007'), 2): 1,
#  (('april-june', '2007', 'completed'), 2): 1,
#  (('2007', 'completed', 'early'), 2): 1,
#  (('completed', 'early', '2008'), 2): 1,
#  (('finnish-owned', 'contract', 'manufacturer'), 3): 1,
#  (('contract', 'manufacturer', 'electronics'), 3): 1,
#  (('manufacturer', 'electronics', 'elcoteq'), 3): 1,
#  (('electronics', 'elcoteq', 'hungary'), 3): 1,
#  (('elcoteq', 'hungary', 'kft'), 3): 1,
#  (('hungary', 'kft', 'announced'), 3): 1,
#  (('kft', 'announced', 'plans'), 3): 1,
#  (('announced', 'plans', 'recruit'), 3): 1,
#  (('plans', 'recruit', '650'), 3): 1,
#  (('recruit', '650', 'new'), 3): 1,
#  (('650', 'new', 'staffers'), 3): 1,
#  (('new', 'staffers', 'fulfill'), 3): 1,
#  (('staffers', 'fulfill', 'new'), 3): 1,
#  (('fulfill', 'new', 'orders'), 3): 1,
#  (('new', 'orders', 'p+_cs'), 3): 1,
#  (('orders', 'p+_cs', 'company'), 3): 1,
#  (('p+_cs', 'company', 'two'), 3): 1,
#  (('company', 'two', 'plants'), 3): 1,
#  (('gross', 'area', 'innova'), 2): 1,
#  (('area', 'innova', '2'), 2): 1,
#  (('innova', '2', 'project'), 2): 1,
#  (('2', 'project', '10,000'), 2): 1,
#  (('project', '10,000', 'sq'), 2): 1,
#  (('10,000', 'sq', '107,600'), 2): 1,
#  (('sq', '107,600', 'sq'), 2): 1,
#  (('107,600', 'sq', 'ft'), 2): 1,
#  (('finnish', 'home', 'decoration'), 2): 1,
#  (('home', 'decoration', 'arts'), 2): 1,
#  (('decoration', 'arts', 'crafts'), 2): 1,
#  (('arts', 'crafts', 'retailer'), 2): 1,
#  (('crafts', 'retailer', 'tiimari'), 2): 1,
#  (('retailer', 'tiimari', 'plc'), 2): 1,
#  (('tiimari', 'plc', 'omx'), 2): 1,
#  (('plc', 'omx', 'helsinki'), 2): 4,
#  (('omx', 'helsinki', 'tii1v'), 2): 1,
#  (('helsinki', 'tii1v', 'reported'), 2): 1,
#  (('tii1v', 'reported', 'monday'), 2): 1,
#  (('reported', 'monday', '18'), 2): 2,
#  (('monday', '18', 'august'), 2): 2,
#  (('18', 'august', 'operating'), 2): 2,
#  (('august', 'operating', 'loss'), 2): 1,
#  (('operating', 'loss', 'eur3'), 2): 1,
#  (('loss', 'eur3', '.3'), 2): 1,
#  (('eur3', '.3', 'net'), 2): 1,
#  (('.3', 'net', 'sales'), 2): 2,
#  (('net', 'sales', 'eur33'), 2): 1,
#  (('sales', 'eur33', '.9'), 2): 1,
#  (('eur33', '.9', 'period'), 2): 1,
#  (('.9', 'period', 'january-june'), 2): 2,
#  (('period', 'january-june', '2008'), 2): 4,
#  (('deliveries', 'start', 'second'), 2): 1,
#  (('start', 'second', 'half'), 2): 1,
#  (('second', 'half', '2007'), 2): 2,
#  (('half', '2007', 'start-up'), 2): 1,
#  (('2007', 'start-up', 'mill'), 2): 1,
#  (('start-up', 'mill', 'scheduled'), 2): 1,
#  (('mill', 'scheduled', '2008'), 2): 1,
#  (('steek', 'set', '2002'), 2): 1,
#  (('set', '2002', 'based'), 2): 1,
#  (('2002', 'based', 'bordeaux'), 2): 1,
#  (('based', 'bordeaux', 'southwestern'), 2): 1,
#  (('bordeaux', 'southwestern', 'france'), 2): 1,
#  (('outotec', 'said', 'new'), 3): 1,
#  (('said', 'new', 'orders'), 3): 1,
#  (('new', 'orders', 'worth'), 3): 2,
#  (('orders', 'worth', '492.9'), 3): 1,
#  (('worth', '492.9', 'mln'), 3): 1,
#  (('492.9', 'mln', 'eur'), 3): 1,
#  (('mln', 'eur', 'quarter'), 3): 1,
#  (('eur', 'quarter', 'compared'), 3): 1,
#  (('quarter', 'compared', '240.4'), 3): 1,
#  (('compared', '240.4', 'mln'), 3): 1,
#  (('240.4', 'mln', 'eur'), 3): 1,
#  (('mln', 'eur', 'year'), 3): 4,
#  (('eur', 'year', 'earlier'), 3): 2,
#  (('store', 'located', 'poznan'), 2): 1,
#  (('located', 'poznan', 'shopping'), 2): 1,
#  (('poznan', 'shopping', 'center'), 2): 1,
#  (('shopping', 'center', 'named'), 2): 1,
#  (('center', 'named', 'pestka'), 2): 1,
#  (('named', 'pestka', 'company'), 2): 1,
#  (('pestka', 'company', 'added'), 2): 1,
#  (('value', 'order', 'usd'), 2): 2,
#  (('order', 'usd', '2.2'), 2): 1,
#  (('usd', '2.2', 'mn'), 2): 1,
#  (('company', 'expects', 'meat'), 2): 1,
#  (('expects', 'meat', 'purchases'), 2): 1,
#  (('meat', 'purchases', 'remain'), 2): 1,
#  (('purchases', 'remain', '8mn'), 2): 1,
#  (('remain', '8mn', 'kilos'), 2): 1,
#  (('8mn', 'kilos', '2011'), 2): 1,
#  (('finnish', 'house', 'manufacturers'), 2): 1,
#  (('house', 'manufacturers', 'targeting'), 2): 1,
#  (('manufacturers', 'targeting', 'strongly'), 2): 1,
#  (('targeting', 'strongly', 'growing'), 2): 1,
#  (('strongly', 'growing', 'one-family'), 2): 1,
#  (('growing', 'one-family', 'house'), 2): 1,
#  (('one-family', 'house', 'market'), 2): 1,
#  (('house', 'market', 'russia'), 2): 1,
#  (('deal', 'worth', 'eur'), 2): 1,
#  (('worth', 'eur', '1.2'), 2): 1,
#  (('eur', '1.2', 'mn'), 2): 1,
#  (('investment', 'investment', 'activity'), 2): 1,
#  (('investment', 'activity', 'communication'), 2): 1,
#  (('activity', 'communication', 'relates'), 2): 1,
#  (('communication', 'relates', 'available'), 2): 1,
#  (('relates', 'available', 'relevant'), 2): 1,
#  (('available', 'relevant', 'persons'), 2): 1,
#  (('relevant', 'persons', 'engaged'), 2): 1,
#  (('persons', 'engaged', 'relevant'), 2): 1,
#  (('engaged', 'relevant', 'persons'), 2): 1,
#  (('following', 'increase', 'company+ï¿½eur'), 2): 1,
#  (('increase', 'company+ï¿½eur', 'tm'), 2): 1,
#  (('company+ï¿½eur', 'tm', 'capital'), 2): 1,
#  (('tm', 'capital', 'totals'), 2): 1,
#  (('capital', 'totals', '5.5'), 2): 1,
#  (('totals', '5.5', 'mln'), 2): 1,
#  (('5.5', 'mln', 'romanian'), 2): 1,
#  (('mln', 'romanian', 'lei'), 2): 1,
#  (('romanian', 'lei', '1.98'), 2): 1,
#  (('lei', '1.98', 'mln-1'), 2): 1,
#  (('1.98', 'mln-1', '.56'), 2): 1,
#  (('mln-1', '.56', 'mln'), 2): 1,
#  (('.56', 'mln', 'euro'), 2): 1,
#  (('since', 'association', "'s"), 1): 1,
#  (('association', "'s", 'data'), 1): 1,
#  (("'s", 'data', 'cover'), 1): 1,
#  (('data', 'cover', 'sales'), 1): 1,
#  (('cover', 'sales', 'figures'), 1): 1,
#  (('sales', 'figures', '100'), 1): 1,
#  (('figures', '100', 'small'), 1): 1,
#  (('100', 'small', 'local'), 1): 1,
#  (('small', 'local', 'breweries'), 1): 1,
#  (('local', 'breweries', 'sales'), 1): 1,
#  (('breweries', 'sales', 'imported'), 1): 1,
#  (('sales', 'imported', 'beer'), 1): 1,
#  (('imported', 'beer', 'products'), 1): 1,
#  (('beer', 'products', 'actual'), 1): 1,
#  (('products', 'actual', 'market'), 1): 1,
#  (('actual', 'market', 'shares'), 1): 1,
#  (('market', 'shares', 'members'), 1): 1,
#  (('shares', 'members', 'smaller'), 1): 1,
#  (('members', 'smaller', 'given'), 1): 1,
#  (('smaller', 'given', 'report'), 1): 1,
#  (('according', 'latvian', 'business'), 1): 1,
#  (('latvian', 'business', 'register'), 1): 1,
#  (('business', 'register', 'uponor'), 1): 1,
#  (('register', 'uponor', 'latvia'), 1): 1,
#  (('uponor', 'latvia', 'closed'), 1): 1,
#  (('latvia', 'closed', 'red'), 1): 1,
#  (('closed', 'red', 'lvl'), 1): 1,
#  (('red', 'lvl', '99,000'), 1): 1,
#  (('lvl', '99,000', 'eur'), 1): 1,
#  (('99,000', 'eur', '139,538.17'), 1): 1,
#  (('eur', '139,538.17', 'usd'), 1): 1,
#  (('139,538.17', 'usd', '194,556.48'), 1): 1,
#  (('usd', '194,556.48', 'turnover'), 1): 1,
#  (('194,556.48', 'turnover', 'lvl'), 1): 1,
#  (('turnover', 'lvl', '2.346'), 1): 1,
#  (('lvl', '2.346', 'mn'), 1): 1,
#  (('2.346', 'mn', '2009'), 1): 1,
#  (('issue', 'came', 'connection'), 2): 1,
#  (('came', 'connection', 'discussion'), 2): 1,
#  (('connection', 'discussion', 'local'), 2): 1,
#  (('discussion', 'local', 'municipalities'), 2): 1,
#  (('local', 'municipalities', 'concerning'), 2): 1,
#  (('municipalities', 'concerning', 'sale'), 2): 1,
#  (('concerning', 'sale', 'water'), 2): 1,
#  (('sale', 'water', 'industrial'), 2): 1,
#  (('water', 'industrial', 'facilities'), 2): 1,
#  (('operating', 'profit', 'rose'), 3): 13,
#  (('profit', 'rose', 'eur'), 3): 20,
#  (('rose', 'eur', '13.1'), 3): 1,
#  (('eur', '13.1', 'mn'), 3): 2,
#  (('13.1', 'mn', 'eur'), 3): 1,
#  (('mn', 'eur', '8.7'), 3): 1,
#  (('eur', '8.7', 'mn'), 3): 1,
#  (('8.7', 'mn', 'corresponding'), 3): 1,
#  (('mn', 'corresponding', 'period'), 3): 19,
#  (('corresponding', 'period', '2007'), 3): 6,
#  (('period', '2007', 'representing'), 3): 1,
#  (('2007', 'representing', '7.7'), 3): 1,
#  (('representing', '7.7', 'net'), 3): 1,
#  (('7.7', 'net', 'sales'), 3): 1,
#  (('annual', 'capacity', '10,000'), 2): 1,
#  (('capacity', '10,000', 'mw'), 2): 1,
#  (('finnish', 'company', 'building'), 2): 1,
#  (('company', 'building', '800,000'), 2): 1,
#  (('building', '800,000', 'mt-year'), 2): 1,
#  (('800,000', 'mt-year', 'biodiesel'), 2): 1,
#  (('mt-year', 'biodiesel', 'plant'), 2): 1,
#  (('biodiesel', 'plant', 'singapore'), 2): 1,
#  (('long-standing', 'partnership', 'commitment'), 3): 1,
#  (('partnership', 'commitment', 'enable'), 3): 1,
#  (('commitment', 'enable', 'parties'), 3): 1,
#  (('enable', 'parties', 'develop'), 3): 1,
#  (('parties', 'develop', 'respective'), 3): 1,
#  (('develop', 'respective', 'operations'), 3): 1,
#  (('respective', 'operations', 'esl'), 3): 1,
#  (('operations', 'esl', 'shipping'), 3): 1,
#  (('esl', 'shipping', 'also'), 3): 1,
#  (('shipping', 'also', 'opportunity'), 3): 1,
#  (('also', 'opportunity', 'update'), 3): 1,
#  (('opportunity', 'update', 'fleet'), 3): 1,
#  (('update', 'fleet', 'improve'), 3): 1,
#  (('fleet', 'improve', 'efficiency'), 3): 1,
#  (('aldata', 'solution', 'global'), 2): 1,
#  (('solution', 'global', 'company'), 2): 1,
#  (('global', 'company', 'engaged'), 2): 1,
#  (('company', 'engaged', 'supplier'), 2): 1,
#  (('engaged', 'supplier', 'consumer'), 2): 1,
#  (('supplier', 'consumer', 'business'), 2): 1,
#  (('consumer', 'business', 'process'), 2): 1,
#  (('business', 'process', 'optimization'), 2): 1,
#  (('process', 'optimization', 'announced'), 2): 1,
#  (('optimization', 'announced', 'details'), 2): 1,
#  (('announced', 'details', 'dollars'), 2): 1,
#  (('details', 'dollars', 'dinosaurs'), 2): 1,
#  (('dollars', 'dinosaurs', 'program'), 2): 1,
#  (('reasons', 'behind', 'estimate'), 2): 1,
#  (('behind', 'estimate', 'include'), 2): 1,
#  (('estimate', 'include', 'rise'), 2): 1,
#  (('include', 'rise', '2008'), 2): 1,
#  (('rise', '2008', 'rent'), 2): 1,
#  (('2008', 'rent', 'levels'), 2): 1,
#  (('rent', 'levels', 'several'), 2): 1,
#  (('levels', 'several', 'fully-leased'), 2): 1,
#  (('several', 'fully-leased', 'office'), 2): 1,
#  (('fully-leased', 'office', 'retail'), 2): 1,
#  (('office', 'retail', 'properties'), 2): 1,
#  (('retail', 'properties', 'completed'), 2): 1,
#  (('properties', 'completed', 'added'), 2): 1,
#  (('completed', 'added', 'company'), 2): 1,
#  (('added', 'company', "'s"), 2): 1,
#  (('company', "'s", 'investment'), 2): 1,
#  (("'s", 'investment', 'property'), 2): 1,
#  (('investment', 'property', 'portfolio'), 2): 1,
#  (('finnish', 'beverage', 'company'), 2): 1,
#  (('beverage', 'company', 'olvi'), 2): 1,
#  (('company', 'olvi', 'introducing'), 2): 1,
#  (('olvi', 'introducing', 'new'), 2): 1,
#  (('introducing', 'new', 'long'), 2): 1,
#  (('new', 'long', 'drink'), 2): 1,
#  (('long', 'drink', 'olvi'), 2): 1,
#  (('drink', 'olvi', 'kultalonkero'), 2): 1,
#  (('olvi', 'kultalonkero', '``'), 2): 1,
#  (('kultalonkero', '``', 'golden'), 2): 1,
#  (('``', 'golden', 'long'), 2): 1,
#  (('golden', 'long', 'drink'), 2): 1,
#  (('long', 'drink', '``'), 2): 1,
#  (('drink', '``', 'market'), 2): 1,
#  (('``', 'market', 'finland'), 2): 1,
#  (('market', 'finland', 'spring'), 2): 1,
#  (('finland', 'spring', '2009'), 2): 1,
#  (('current', 'reference', 'grade'), 1): 1,
#  (('reference', 'grade', 'instruments'), 1): 1,
#  (('grade', 'instruments', 'challenging'), 1): 1,
#  (('instruments', 'challenging', 'operate'), 1): 1,
#  (('challenging', 'operate', 'due'), 1): 1,
#  (('operate', 'due', 'high'), 1): 1,
#  (('due', 'high', 'price'), 1): 1,
#  (('high', 'price', 'complexity'), 1): 1,
#  (('price', 'complexity', 'routine'), 1): 1,
#  (('complexity', 'routine', 'use'), 1): 1,
#  (('rental', 'building', 'equipment'), 2): 1,
#  (('building', 'equipment', 'accounted'), 2): 1,
#  (('equipment', 'accounted', '88'), 2): 1,
#  (('accounted', '88', 'percent'), 2): 1,
#  (('88', 'percent', 'operating'), 2): 1,
#  (('percent', 'operating', 'income'), 2): 1,
#  (('piloting', 'instrument', 'developed'), 2): 1,
#  (('instrument', 'developed', 'according'), 2): 1,
#  (('developed', 'according', 'experiences'), 2): 1,
#  (('according', 'experiences', 'gained'), 2): 1,
#  (('goal', 'achieved', 'via'), 2): 1,
#  (('achieved', 'via', 'organic'), 2): 1,
#  (('via', 'organic', 'growth'), 2): 1,
#  (('organic', 'growth', 'possibly'), 2): 1,
#  (('growth', 'possibly', 'supplemented'), 2): 1,
#  (('possibly', 'supplemented', 'acquisitions'), 2): 1,
#  (('operating', 'profit', 'fell'), 1): 9,
#  (('profit', 'fell', 'eur'), 1): 9,
#  (('fell', 'eur', '7.9'), 1): 1,
#  (('eur', '7.9', 'mn'), 1): 1,
#  (('7.9', 'mn', 'second'), 1): 1,
#  (('mn', 'second', 'quarter'), 1): 8,
#  (('second', 'quarter', '2005'), 1): 2,
#  (('quarter', '2005', 'eur'), 1): 1,
#  (('2005', 'eur', '5.1'), 1): 1,
#  (('eur', '5.1', 'mn'), 1): 1,
#  (('5.1', 'mn', 'second'), 1): 1,
#  (('second', 'quarter', '2006'), 1): 1,
#  (('3c', 'expo', 'signature'), 2): 1,
#  (('expo', 'signature', 'show'), 2): 1,
#  (('signature', 'show', 'dongguan'), 2): 1,
#  (('show', 'dongguan', 'supported'), 2): 1,
#  (('dongguan', 'supported', 'dongguan'), 2): 1,
#  (('supported', 'dongguan', 'municipal'), 2): 1,
#  (('dongguan', 'municipal', 'government'), 2): 1,
#  (('municipal', 'government', 'every'), 2): 1,
#  (('government', 'every', 'year'), 2): 1,
#  (('every', 'year', 'featuring'), 2): 1,
#  (('year', 'featuring', 'computer'), 2): 1,
#  (('featuring', 'computer', 'accessories'), 2): 1,
#  (('computer', 'accessories', 'software'), 2): 1,
#  (('accessories', 'software', 'communication'), 2): 1,
#  (('software', 'communication', 'network'), 2): 1,
#  (('communication', 'network', 'products'), 2): 1,
#  (('ruukki', 'romania', 'local'), 3): 1,
#  (('romania', 'local', 'arm'), 3): 1,
#  (('local', 'arm', 'finnish'), 3): 1,
#  (('arm', 'finnish', 'metal'), 3): 1,
#  (('finnish', 'metal', 'producer'), 3): 1,
#  (('metal', 'producer', 'ruukki'), 3): 1,
#  (('producer', 'ruukki', 'increased'), 3): 1,
#  (('ruukki', 'increased', 'capital'), 3): 1,
#  (('increased', 'capital', '900,000'), 3): 1,
#  (('capital', '900,000', 'euro'), 3): 1,
#  (('900,000', 'euro', '1.14'), 3): 1,
#  (('euro', '1.14', 'mln'), 3): 1,
#  (('1.14', 'mln', 'cash'), 3): 1,
#  (('mln', 'cash', 'contribution'), 3): 1,
#  (('cash', 'contribution', 'reported'), 3): 1,
#  (('contribution', 'reported', 'september'), 3): 1,
#  (('reported', 'september', '19'), 3): 1,
#  (('september', '19', '2006'), 3): 1,
#  (('nokia', 'u.s.', 'shares'), 1): 1,
#  (('u.s.', 'shares', '3.3'), 1): 1,
#  (('shares', '3.3', 'percent'), 1): 1,
#  (('3.3', 'percent', 'lower'), 1): 1,
#  (('percent', 'lower', '12.73'), 1): 1,
#  (('lower', '12.73', '1750'), 1): 1,
#  (('12.73', '1750', 'gmt'), 1): 1,
#  (('finnish', 'component', 'supplier'), 2): 1,
#  (('component', 'supplier', 'componenta'), 2): 1,
#  (('supplier', 'componenta', 'corporation'), 2): 1,
#  (('componenta', 'corporation', 'omx'), 2): 1,
#  (('corporation', 'omx', 'helsinki'), 2): 7,
#  (('omx', 'helsinki', 'cth1v'), 2): 1,
#  (('helsinki', 'cth1v', 'reported'), 2): 1,
#  (('cth1v', 'reported', 'tuesday'), 2): 1,
#  (('reported', 'tuesday', '15'), 2): 1,
#  (('tuesday', '15', 'july'), 2): 1,
#  (('15', 'july', 'operating'), 2): 1,
#  (('july', 'operating', 'profit'), 2): 1,
#  (('operating', 'profit', 'eur46'), 2): 1,
#  (('profit', 'eur46', '.2'), 2): 1,
#  (('eur46', '.2', 'net'), 2): 1,
#  (('.2', 'net', 'sales'), 2): 1,
#  (('net', 'sales', 'eur386'), 2): 1,
#  (('sales', 'eur386', '.0'), 2): 1,
#  (('eur386', '.0', 'financial'), 2): 1,
#  (('.0', 'financial', 'period'), 2): 1,
#  (('financial', 'period', 'january-june'), 2): 1,
#  (('elite', 'residence', 'tower'), 2): 1,
#  (('residence', 'tower', 'new'), 2): 1,
#  (('tower', 'new', 'development'), 2): 1,
#  (('new', 'development', 'tameer'), 2): 1,
#  (('development', 'tameer', 'located'), 2): 1,
#  (('tameer', 'located', 'heart'), 2): 1,
#  (('located', 'heart', 'dubai'), 2): 1,
#  (('heart', 'dubai', 'marina'), 2): 1,
#  (('lay-offs', 'affect', '240'), 1): 1,
#  (('affect', '240', 'people'), 1): 1,
#  (('240', 'people', 'total'), 1): 1,
#  (('people', 'total', '320'), 1): 1,
#  (('total', '320', 'okmetic'), 1): 1,
#  (('320', 'okmetic', 'employees'), 1): 1,
#  (('okmetic', 'employees', 'finland'), 1): 1,
#  (('``', 'agreement', 'continue'), 3): 1,
#  (('agreement', 'continue', 'good'), 3): 1,
#  (('continue', 'good', 'cooperationand'), 3): 1,
#  (('good', 'cooperationand', 'time'), 3): 1,
#  (('cooperationand', 'time', 'release'), 3): 1,
#  (('time', 'release', 'capital'), 3): 1,
#  (('release', 'capital', 'tied'), 3): 1,
#  (('capital', 'tied', 'ourmachinery'), 3): 1,
#  (('tied', 'ourmachinery', 'operation'), 3): 1,
#  (('travel', 'expenses', 'would'), 2): 1,
#  (('expenses', 'would', 'reimbursed'), 2): 1,
#  (('would', 'reimbursed', 'accordance'), 2): 1,
#  (('reimbursed', 'accordance', 'travel'), 2): 1,
#  (('accordance', 'travel', 'policy'), 2): 1,
#  (('travel', 'policy', 'company'), 2): 1,
#  (('ahlstrom', 'corporation', 'anne'), 2): 1,
#  (('corporation', 'anne', 'pirila'), 2): 1,
#  (('anne', 'pirila', 'director'), 2): 1,
#  (('pirila', 'director', 'financial'), 2): 1,
#  (('director', 'financial', 'communications'), 2): 1,
#  (('financial', 'communications', 'distribution'), 2): 1,
#  (('communications', 'distribution', 'helsinki'), 2): 1,
#  (('distribution', 'helsinki', 'stock'), 2): 1,
#  (('helsinki', 'stock', 'exchange'), 2): 7,
#  (('stock', 'exchange', 'main'), 2): 2,
#  (('exchange', 'main', 'media'), 2): 1,
#  (('main', 'media', 'ahlstrom'), 2): 1,
#  (('media', 'ahlstrom', 'brief'), 2): 1,
#  (('ahlstrom', 'brief', 'ahlstrom'), 2): 1,
#  (('brief', 'ahlstrom', 'leader'), 2): 1,
#  (('ahlstrom', 'leader', 'development'), 2): 1,
#  (('leader', 'development', 'manufacture'), 2): 1,
#  (('development', 'manufacture', 'marketing'), 2): 2,
#  (('manufacture', 'marketing', 'high'), 2): 2,
#  (('marketing', 'high', 'performance'), 2): 2,
#  (('high', 'performance', 'fiber-based'), 2): 2,
#  (('performance', 'fiber-based', 'materials'), 2): 2,
#  (('2007', 'almost', 'two'), 2): 1,
#  (('almost', 'two', 'thirds'), 2): 1,
#  (('two', 'thirds', 'orion'), 2): 1,
#  (('thirds', 'orion', "'s"), 2): 1,
#  (('orion', "'s", 'net'), 2): 1,
#  (("'s", 'net', 'sales'), 2): 14,
#  (('net', 'sales', 'came'), 2): 1,
#  (('sales', 'came', 'drugs'), 2): 1,
#  (('net', 'income', 'life'), 3): 2,
#  (('income', 'life', 'insurance'), 3): 2,
#  (('life', 'insurance', 'doubled'), 3): 1,
#  (('insurance', 'doubled', 'eur'), 3): 1,
#  (('doubled', 'eur', '6.8'), 3): 1,
#  (('eur', '6.8', 'mn'), 3): 2,
#  (('6.8', 'mn', 'eur'), 3): 1,
#  (('mn', 'eur', '3.2'), 3): 1,
#  (('eur', '3.2', 'mn'), 3): 1,
#  (('3.2', 'mn', 'net'), 3): 1,
#  (('mn', 'net', 'income'), 3): 2,
#  (('net', 'income', 'non-life'), 3): 2,
#  (('income', 'non-life', 'insurance'), 3): 2,
#  (('non-life', 'insurance', 'rose'), 3): 1,
#  (('insurance', 'rose', 'eur'), 3): 2,
#  (('rose', 'eur', '5.2'), 3): 1,
#  (('eur', '5.2', 'mn'), 3): 1,
#  (('5.2', 'mn', 'eur'), 3): 1,
#  (('mn', 'eur', '1.5'), 3): 1,
#  (('eur', '1.5', 'mn'), 3): 1,
#  (('1.5', 'mn', 'corresponding'), 3): 1,
#  (('corresponding', 'period', '2009'), 3): 12,
#  (('according', 'aktia', 'asset'), 1): 1,
#  (('aktia', 'asset', 'management'), 1): 1,
#  (('asset', 'management', 'finnish'), 1): 1,
#  (('management', 'finnish', 'analysts'), 1): 1,
#  (('finnish', 'analysts', 'forecasts'), 1): 1,
#  (('analysts', 'forecasts', '2009'), 1): 1,
#  (('forecasts', '2009', 'still'), 1): 1,
#  (('2009', 'still', 'high'), 1): 1,
#  (('ramirent', 'leading', 'construction'), 3): 1,
#  (('leading', 'construction', 'machinery'), 3): 1,
#  (('construction', 'machinery', 'rental'), 3): 1,
#  (('machinery', 'rental', 'company'), 3): 2,
#  (('rental', 'company', 'finland'), 3): 1,
#  (('company', 'finland', 'annual'), 3): 1,
#  (('finland', 'annual', 'sales'), 3): 1,
#  (('annual', 'sales', 'eur'), 3): 1,
#  (('sales', 'eur', '134'), 3): 1,
#  (('eur', '134', 'million'), 3): 1,
#  (('134', 'million', '2009'), 3): 1,
#  (('million', '2009', 'operating'), 3): 1,
#  (('2009', 'operating', 'nationwide'), 3): 1,
#  (('operating', 'nationwide', '83'), 3): 1,
#  (('nationwide', '83', 'outlets'), 3): 1,
#  (('83', 'outlets', '612'), 3): 1,
#  (('outlets', '612', 'employees'), 3): 1,
#  (('2006', 'teliasonera', 'net'), 2): 1,
#  (('teliasonera', 'net', 'sales'), 2): 1,
#  (('net', 'sales', 'sek'), 2): 1,
#  (('sales', 'sek', '91'), 2): 1,
#  (('sek', '91', 'bn'), 2): 1,
#  (('91', 'bn', 'ebitda'), 2): 1,
#  (('bn', 'ebitda', 'sek'), 2): 1,
#  (('ebitda', 'sek', '32.266'), 2): 1,
#  (('sek', '32.266', 'bn'), 2): 1,
#  (('32.266', 'bn', 'net'), 2): 1,
#  (('bn', 'net', 'income'), 2): 1,
#  (('net', 'income', 'sek'), 2): 1,
#  (('income', 'sek', '19.28'), 2): 1,
#  (('sek', '19.28', 'bn'), 2): 1,
#  (('chain', 'posted', 'sales'), 3): 1,
#  (('posted', 'sales', '298'), 3): 1,
#  (('sales', '298', 'million'), 3): 1,
#  (('298', 'million', 'euros'), 3): 1,
#  (('million', 'euros', 'full'), 3): 1,
#  (('euros', 'full', '2005'), 3): 1,
#  (('full', '2005', 'rise'), 3): 1,
#  (('2005', 'rise', '19.5'), 3): 1,
#  (('rise', '19.5', 'percent'), 3): 1,
#  (('19.5', 'percent', 'year-on-year'), 3): 1,
#  (('scanfil', 'expects', 'net'), 2): 1,
#  (('expects', 'net', 'sales'), 2): 6,
#  (('net', 'sales', '2008'), 2): 5,
#  (('sales', '2008', 'remain'), 2): 1,
#  (('2008', 'remain', '2007'), 2): 1,
#  (('remain', '2007', 'level'), 2): 1,
#  (('profit', 'taxes', 'eur'), 2): 4,
#  (('taxes', 'eur', '57.7'), 2): 1,
#  (('eur', '57.7', '11.1'), 2): 1,
#  (('57.7', '11.1', 'million'), 2): 1,
#  (('company', 'also', 'appointed'), 2): 1,
#  (('also', 'appointed', 'leif'), 2): 1,
#  (('appointed', 'leif', 'rosen'), 2): 1,
#  (('leif', 'rosen', 'head'), 2): 1,
#  (('rosen', 'head', 'special'), 2): 1,
#  (('head', 'special', 'plate'), 2): 1,
#  (('special', 'plate', 'unit'), 2): 1,
#  (('plate', 'unit', 'includes'), 2): 1,
#  (('unit', 'includes', 'quarto'), 2): 1,
#  (('includes', 'quarto', 'plate'), 2): 1,
#  (('quarto', 'plate', 'units'), 2): 1,
#  (('plate', 'units', 'degerfors'), 2): 1,
#  (('units', 'degerfors', 'sweden'), 2): 1,
#  (('degerfors', 'sweden', 'new'), 2): 1,
#  (('sweden', 'new', 'castle'), 2): 1,
#  (('new', 'castle', 'usa'), 2): 1,
#  (('castle', 'usa', 'unit'), 2): 1,
#  (('usa', 'unit', 'willich'), 2): 1,
#  (('unit', 'willich', 'germany'), 2): 1,
#  (('willich', 'germany', 'well'), 2): 1,
#  (('germany', 'well', 'pressplate'), 2): 1,
#  (('well', 'pressplate', 'prefab'), 2): 1,
#  (('pressplate', 'prefab', 'avesta'), 2): 1,
#  (('prefab', 'avesta', 'plate'), 2): 1,
#  (('avesta', 'plate', 'service'), 2): 1,
#  (('plate', 'service', 'centre'), 2): 1,
#  (('service', 'centre', 'nordic'), 2): 1,
#  (('centre', 'nordic', 'degerfors'), 2): 1,
#  (('``', 'upm', "'s"), 3): 1,
#  (('upm', "'s", 'deliveries'), 3): 1,
#  (("'s", 'deliveries', 'increased'), 3): 1,
#  (('deliveries', 'increased', 'third'), 3): 1,
#  (('increased', 'third', 'quarter'), 3): 1,
#  (('third', 'quarter', '4'), 3): 1,
#  (('quarter', '4', 'percent'), 3): 1,
#  (('4', 'percent', 'efficiency'), 3): 1,
#  (('percent', 'efficiency', 'operations'), 3): 1,
#  (('efficiency', 'operations', 'improved'), 3): 1,
#  (('operations', 'improved', '``'), 3): 1,
#  (('improved', '``', 'chief'), 3): 1,
#  (('``', 'chief', 'executive'), 3): 2,
#  (('chief', 'executive', 'jussi'), 3): 1,
#  (('executive', 'jussi', 'pesonen'), 3): 1,
#  (('jussi', 'pesonen', 'said'), 3): 1,
#  (('operating', 'profit', '12-month'), 1): 4,
#  (('profit', '12-month', 'period'), 1): 4,
#  (('12-month', 'period', 'decreased'), 1): 5,
#  (('period', 'decreased', 'eur2'), 1): 1,
#  (('decreased', 'eur2', '.9'), 1): 1,
#  (('eur2', '.9', 'turnover'), 1): 1,
#  (('.9', 'turnover', 'increased'), 1): 1,
#  (('turnover', 'increased', 'eur24'), 1): 1,
#  (('increased', 'eur24', '.5'), 1): 1,
#  (('eur24', '.5', 'compared'), 1): 1,
#  (('.5', 'compared', 'financial'), 1): 1,
#  (('compared', 'financial', 'year'), 1): 3,
#  (('financial', 'year', '2004'), 1): 3,
#  (('cents', 'profile', 'contains'), 2): 1,
#  (('profile', 'contains', 'business'), 2): 1,
#  (('contains', 'business', 'operations'), 2): 1,
#  (('business', 'operations', 'company'), 2): 2,
#  (('operations', 'company', 'history'), 2): 1,
#  (('company', 'history', 'major'), 2): 1,
#  (('history', 'major', 'products'), 2): 1,
#  (('major', 'products', 'services'), 2): 1,
#  (('products', 'services', 'prospects'), 2): 1,
#  (('services', 'prospects', 'key'), 2): 1,
#  (('prospects', 'key', 'competitors'), 2): 1,
#  (('key', 'competitors', 'structure'), 2): 1,
#  (('competitors', 'structure', 'key'), 2): 1,
#  (('structure', 'key', 'employees'), 2): 1,
#  (('key', 'employees', 'locations'), 2): 1,
#  (('employees', 'locations', 'subsidiaries'), 2): 1,
#  (('profit', 'taxes', 'period'), 3): 1,
#  (('taxes', 'period', 'eur0'), 3): 1,
#  (('period', 'eur0', '.9'), 3): 1,
#  (('eur0', '.9', 'eur0'), 3): 1,
#  (('.9', 'eur0', '.01'), 3): 1,
#  (('eur0', '.01', 'last'), 3): 1,
#  (('.01', 'last', 'year'), 3): 1,
#  (('newly-completed', 'allure', 'seas'), 2): 1,
#  (('allure', 'seas', 'identical'), 2): 1,
#  (('seas', 'identical', 'sister'), 2): 1,
#  (('identical', 'sister', 'ship'), 2): 1,
#  (('sister', 'ship', 'oasis'), 2): 1,
#  (('ship', 'oasis', 'seas'), 2): 1,
#  (('oasis', 'seas', 'completed'), 2): 1,
#  (('seas', 'completed', 'last'), 2): 1,
#  (('completed', 'last', 'year'), 2): 2,
#  (('last', 'year', 'world'), 2): 1,
#  (('year', 'world', "'s"), 2): 1,
#  (('world', "'s", 'largest'), 2): 2,
#  (("'s", 'largest', 'cruise'), 2): 1,
#  (('largest', 'cruise', 'ships'), 2): 1,
#  (('number', 'class', 'shares'), 2): 1,
#  (('class', 'shares', 'remains'), 2): 1,
#  (('shares', 'remains', 'unchanged'), 2): 1,
#  (('remains', 'unchanged', '9,526,089'), 2): 1,
#  (('unchanged', '9,526,089', 'shares'), 2): 1,
#  (('rental', 'agreement', 'stockmann'), 2): 1,
#  (('agreement', 'stockmann', 'committed'), 2): 1,
#  (('stockmann', 'committed', 'invest'), 2): 1,
#  (('committed', 'invest', 'building'), 2): 1,
#  (('invest', 'building', 'bridge'), 2): 1,
#  (('building', 'bridge', 'gogol'), 2): 1,
#  (('bridge', 'gogol', 'street'), 2): 1,
#  (('gogol', 'street', 'build'), 2): 1,
#  (('street', 'build', 'underground'), 2): 1,
#  (('build', 'underground', 'tunnel'), 2): 1,
#  (('underground', 'tunnel', 'crossing'), 2): 1,
#  (('tunnel', 'crossing', 'street'), 2): 1,
#  (('crossing', 'street', '2004'), 2): 1,
#  (('honkarakenne', "'s", 'customer'), 2): 1,
#  (("'s", 'customer', 'project'), 2): 1,
#  (('customer', 'project', 'one'), 2): 1,
#  (('project', 'one', 'biggest'), 2): 1,
#  (('one', 'biggest', 'real'), 2): 1,
#  (('biggest', 'real', 'estate'), 2): 1,
#  (('real', 'estate', 'companies'), 2): 2,
#  (('estate', 'companies', 'kazakhstan'), 2): 1,
#  (('companies', 'kazakhstan', 'according'), 2): 1,
#  (('kazakhstan', 'according', 'company'), 2): 1,
#  (('new', 'deal', 'strengthened'), 3): 1,
#  (('deal', 'strengthened', 'partnership'), 3): 1,
#  (('strengthened', 'partnership', 'telemig'), 3): 1,
#  (('partnership', 'telemig', 'celular'), 3): 1,
#  (('telemig', 'celular', 'tecnomen'), 3): 1,
#  (('celular', 'tecnomen', 'started'), 3): 1,
#  (('tecnomen', 'started', 'since'), 3): 1,
#  (('started', 'since', 'beginning'), 3): 1,
#  (('since', 'beginning', 'telemig'), 3): 1,
#  (('beginning', 'telemig', "'s"), 3): 1,
#  (('telemig', "'s", 'prepaid'), 3): 1,
#  (("'s", 'prepaid', 'operations'), 3): 1,
#  (('turun', 'kaupunkin', 'finland'), 3): 1,
#  (('kaupunkin', 'finland', 'based'), 3): 1,
#  (('finland', 'based', 'company'), 3): 2,
#  (('based', 'company', 'awarded'), 3): 2,
#  (('company', 'awarded', 'contract'), 3): 2,
#  (('awarded', 'contract', 'lemminkainen'), 3): 1,
#  (('contract', 'lemminkainen', 'talotekniikka'), 3): 1,
#  (('lemminkainen', 'talotekniikka', 'oy'), 3): 1,
#  (('talotekniikka', 'oy', 'electrical'), 3): 1,
#  (('oy', 'electrical', 'installation'), 3): 1,
#  (('electrical', 'installation', 'work'), 3): 1,
#  (('based', 'first', 'quarter'), 1): 1,
#  (('first', 'quarter', 'result'), 1): 2,
#  (('quarter', 'result', 'existing'), 1): 1,
#  (('result', 'existing', 'order'), 1): 1,
#  (('existing', 'order', 'backlog'), 1): 1,
#  (('order', 'backlog', 'new'), 1): 1,
#  (('backlog', 'new', 'order'), 1): 1,
#  (('new', 'order', 'prospects'), 1): 1,
#  (('order', 'prospects', 'company'), 1): 1,
#  (('prospects', 'company', 'expects'), 1): 1,
#  (('company', 'expects', 'full-year'), 1): 1,
#  (('expects', 'full-year', 'sales'), 1): 1,
#  (('full-year', 'sales', 'contract'), 1): 1,
#  (('sales', 'contract', '25'), 1): 1,
#  (('contract', '25', '2008'), 1): 1,
#  (('25', '2008', 'gross'), 1): 1,
#  (('2008', 'gross', 'margin'), 1): 1,
#  (('gross', 'margin', 'stay'), 1): 1,
#  (('margin', 'stay', 'healthy'), 1): 1,
#  (('stay', 'healthy', 'level'), 1): 1,
#  (('healthy', 'level', 'operating'), 1): 1,
#  (('level', 'operating', 'profit'), 1): 1,
#  (('operating', 'profit', 'margin'), 1): 1,
#  (('profit', 'margin', 'lower'), 1): 1,
#  (('margin', 'lower', '2008'), 1): 1,
#  (('lower', '2008', 'due'), 1): 1,
#  (('2008', 'due', 'lower'), 1): 1,
#  (('due', 'lower', 'sales'), 1): 1,
#  (('lower', 'sales', 'volume'), 1): 1,
#  (('audio', 'webcast', 'available'), 2): 1,
#  (('webcast', 'available', 'live'), 2): 1,
#  (('available', 'live', 'archived'), 2): 1,
#  (('live', 'archived', 'cerner'), 2): 1,
#  (('archived', 'cerner', "'s"), 2): 1,
#  (('cerner', "'s", 'web'), 2): 1,
#  (("'s", 'web', 'site'), 2): 1,
#  (('web', 'site', 'www.cerner.com'), 2): 1,
#  (('earnings', 'per', 'share'), 3): 14,
#  (('per', 'share', 'eps'), 3): 9,
#  (('share', 'eps', 'first'), 3): 1,
#  (('eps', 'first', 'quarter'), 3): 1,
#  (('first', 'quarter', '2007'), 3): 1,
#  (('quarter', '2007', 'amounted'), 3): 1,
#  (('2007', 'amounted', 'eur0'), 3): 1,
#  (('amounted', 'eur0', '.07'), 3): 1,
#  (('eur0', '.07', 'eur0'), 3): 1,
#  (('.07', 'eur0', '.04'), 3): 1,
#  (('transaction', 'agreement', 'metsaliitto'), 2): 1,
#  (('agreement', 'metsaliitto', 'purchase'), 2): 1,
#  (('metsaliitto', 'purchase', '24.7'), 2): 1,
#  (('purchase', '24.7', 'metsa-botnia'), 2): 1,
#  (('24.7', 'metsa-botnia', "'s"), 2): 1,
#  (('metsa-botnia', "'s", 'shares'), 2): 1,
#  (("'s", 'shares', 'upm'), 2): 1,
#  (('shares', 'upm', '3'), 2): 1,
#  (('upm', '3', 'm-real'), 2): 1,
#  (('skf', '6', 'april'), 3): 1,
#  (('6', 'april', '2010'), 3): 1,
#  (('april', '2010', 'alandsbanken'), 3): 1,
#  (('2010', 'alandsbanken', 'given'), 3): 1,
#  (('alandsbanken', 'given', '``'), 3): 1,
#  (('given', '``', 'buy'), 3): 1,
#  (('``', 'buy', '``'), 3): 2,
#  (('buy', '``', 'recommendation'), 3): 2,
#  (('``', 'recommendation', 'swedish'), 3): 1,
#  (('recommendation', 'swedish', 'industrial'), 3): 1,
#  (('swedish', 'industrial', 'company'), 3): 1,
#  (('industrial', 'company', 'skf'), 3): 1,
#  (('company', 'skf', 'ab'), 3): 1,
#  (('skf', 'ab', 'sto'), 3): 1,
#  (('ab', 'sto', 'skf'), 3): 1,
#  (('sto', 'skf', 'b'), 3): 1,
#  (('skf', 'b', 'share'), 3): 1,
#  (('b', 'share', 'price'), 3): 1,
#  (('share', 'price', 'target'), 3): 2,
#  (('price', 'target', 'sek150'), 3): 1,
#  (('return', 'investment', '16.6'), 3): 1,
#  (('investment', '16.6', 'compared'), 3): 1,
#  (('16.6', 'compared', '15.8'), 3): 1,
#  (('compared', '15.8', '2004'), 3): 1,
#  (('citigroup', 'inc', 'nyse'), 2): 1,
#  (('inc', 'nyse', 'c'), 2): 1,
#  (('nyse', 'c', 'deutsche'), 2): 1,
#  (('c', 'deutsche', 'bank'), 2): 1,
#  (('deutsche', 'bank', 'nyse'), 2): 1,
#  (('bank', 'nyse', 'db'), 2): 1,
#  (('nyse', 'db', 'pohjola'), 2): 1,
#  (('db', 'pohjola', 'bank'), 2): 1,
#  (('pohjola', 'bank', 'lead'), 2): 1,
#  (('bank', 'lead', 'managers'), 2): 1,
#  (('lead', 'managers', 'sale'), 2): 1,
#  (('group', '-ï¿½', 'profit'), 2): 1,
#  (('-ï¿½', 'profit', 'taxes'), 2): 1,
#  (('taxes', 'eur', '0,2'), 2): 1,
#  (('eur', '0,2', '7,8'), 2): 1,
#  (('0,2', '7,8', 'million'), 2): 1,
#  (('company', 'wide', 'selection'), 2): 1,
#  (('wide', 'selection', 'metal'), 2): 1,
#  (('selection', 'metal', 'products'), 2): 1,
#  (('metal', 'products', 'services'), 2): 1,
#  (('operating', 'profit', 'turnover'), 3): 4,
#  (('profit', 'turnover', 'three-month'), 3): 1,
#  (('turnover', 'three-month', 'period'), 3): 1,
#  (('three-month', 'period', 'increased'), 3): 4,
#  (('period', 'increased', 'respectively'), 3): 12,
#  (('increased', 'respectively', 'eur0'), 3): 3,
#  (('respectively', 'eur0', '.9'), 3): 1,
#  (('eur0', '.9', 'eur8'), 3): 1,
#  (('.9', 'eur8', '.3'), 3): 1,
#  (('eur8', '.3', 'compared'), 3): 1,
#  (('.3', 'compared', 'corresponding'), 3): 1,
#  (('compared', 'corresponding', 'period'), 3): 12,
#  (('corresponding', 'period', '2005'), 3): 9,
#  (('elcoteq', "'s", 'revenues'), 2): 1,
#  (("'s", 'revenues', '2007'), 2): 1,
#  (('revenues', '2007', 'approximately'), 2): 1,
#  (('2007', 'approximately', 'eur'), 2): 1,
#  (('approximately', 'eur', '120'), 2): 1,
#  (('eur', '120', 'million'), 2): 1,
#  (('previously', 'vaahto', 'pulp'), 2): 1,
#  (('vaahto', 'pulp', 'supplied'), 2): 1,
#  (('pulp', 'supplied', 'headboxes'), 2): 1,
#  (('supplied', 'headboxes', 'rectifier'), 2): 1,
#  (('headboxes', 'rectifier', 'roll'), 2): 1,
#  (('rectifier', 'roll', 'dilution'), 2): 1,
#  (('roll', 'dilution', 'control'), 2): 1,
#  (('dilution', 'control', 'technology'), 2): 1,
#  (('control', 'technology', 'stora'), 2): 1,
#  (('technology', 'stora', 'enso'), 2): 1,
#  (('stora', 'enso', "'s"), 2): 3,
#  (('enso', "'s", 'mill'), 2): 1,
#  (("'s", 'mill', 'imatra'), 2): 1,
#  (('mill', 'imatra', 'eastern'), 2): 1,
#  (('imatra', 'eastern', 'finland'), 2): 1,
#  (('``', 'vessel', 'order'), 3): 1,
#  (('vessel', 'order', 'help'), 3): 1,
#  (('order', 'help', 'aspo'), 3): 1,
#  (('help', 'aspo', 'secure'), 3): 1,
#  (('aspo', 'secure', 'long-term'), 3): 1,
#  (('secure', 'long-term', 'competitiveness'), 3): 1,
#  (('long-term', 'competitiveness', 'fleet'), 3): 1,
#  (('competitiveness', 'fleet', 'terms'), 3): 1,
#  (('fleet', 'terms', 'technology'), 3): 1,
#  (('terms', 'technology', 'pricing'), 3): 1,
#  (('aspocomp', 'intends', 'set'), 2): 1,
#  (('intends', 'set', 'plant'), 2): 1,
#  (('set', 'plant', 'manufacture'), 2): 1,
#  (('plant', 'manufacture', 'printed'), 2): 1,
#  (('manufacture', 'printed', 'circuit'), 2): 1,
#  (('printed', 'circuit', 'boards'), 2): 3,
#  (('circuit', 'boards', 'investment'), 2): 1,
#  (('boards', 'investment', 'rs310'), 2): 1,
#  (('investment', 'rs310', 'crore'), 2): 1,
#  (('finnish', 'company', 'sold'), 2): 1,
#  (('company', 'sold', 'uk'), 2): 1,
#  (('sold', 'uk', 'operation'), 2): 1,
#  (('uk', 'operation', 'consisting'), 2): 1,
#  (('operation', 'consisting', '50'), 2): 1,
#  (('consisting', '50', 'staff'), 2): 1,
#  (('50', 'staff', 'offices'), 2): 1,
#  (('staff', 'offices', 'london'), 2): 1,
#  (('offices', 'london', 'birmingham'), 2): 1,
#  (('london', 'birmingham', 'manchester'), 2): 1,
#  (('birmingham', 'manchester', 'part'), 2): 1,
#  (('manchester', 'part', 'deal'), 2): 1,
#  (('part', 'deal', 'hampden'), 2): 1,
#  (('deal', 'hampden', 'july'), 2): 1,
#  (('hampden', 'july', '2001'), 2): 1,
#  (('july', '2001', 'european-wide'), 2): 1,
#  (('2001', 'european-wide', 'property'), 2): 1,
#  (('european-wide', 'property', 'casualty'), 2): 1,
#  (('property', 'casualty', 'arm'), 2): 1,
#  (('casualty', 'arm', 'sampo'), 2): 1,
#  (('arm', 'sampo', 'industrial'), 2): 1,
#  (('aspo', 'serves', 'demanding'), 2): 1,
#  (('serves', 'demanding', 'business-to-business'), 2): 1,
#  (('demanding', 'business-to-business', 'customers'), 2): 1,
#  (('tikkurila', 'division', 'kemira'), 2): 1,
#  (('division', 'kemira', 'group'), 2): 1,
#  (('kemira', 'group', 'controls'), 2): 1,
#  (('group', 'controls', '23'), 2): 1,
#  (('controls', '23', 'russian'), 2): 1,
#  (('23', 'russian', 'market'), 2): 1,
#  (('russian', 'market', 'field'), 2): 1,
#  (('market', 'field', 'owns'), 2): 1,
#  (('field', 'owns', 'st.'), 2): 1,
#  (('owns', 'st.', 'petersburg'), 2): 1,
#  (('st.', 'petersburg', 'paint'), 2): 1,
#  (('petersburg', 'paint', 'producer'), 2): 1,
#  (('paint', 'producer', 'tex'), 2): 1,
#  (('viking', 'line', "'s"), 3): 1,
#  (('line', "'s", 'cargo'), 3): 1,
#  (("'s", 'cargo', 'revenue'), 3): 1,
#  (('cargo', 'revenue', 'increased'), 3): 1,
#  (('revenue', 'increased', '5.4'), 3): 1,
#  (('increased', '5.4', 'eur'), 3): 1,
#  (('5.4', 'eur', '21.46'), 3): 1,
#  (('eur', '21.46', 'mn'), 3): 1,
#  (('21.46', 'mn', 'cargo'), 3): 1,
#  (('mn', 'cargo', 'volume'), 3): 1,
#  (('cargo', 'volume', 'increased'), 3): 2,
#  (('volume', 'increased', '2.4'), 3): 1,
#  (('increased', '2.4', '70,116'), 3): 1,
#  (('2.4', '70,116', 'cargo'), 3): 1,
#  (('70,116', 'cargo', 'units'), 3): 1,
#  (('internal', 'revenue', 'service'), 2): 1,
#  (('revenue', 'service', 'sees'), 2): 1,
#  (('service', 'sees', '20'), 2): 1,
#  (('sees', '20', 'percent'), 2): 1,
#  (('20', 'percent', 'taxpayers'), 2): 1,
#  (('percent', 'taxpayers', 'wait'), 2): 1,
#  (('taxpayers', 'wait', 'last'), 2): 1,
#  (('wait', 'last', 'two'), 2): 1,
#  (('last', 'two', 'weeks'), 2): 1,
#  (('two', 'weeks', 'file'), 2): 1,
#  (('weeks', 'file', '40'), 2): 1,
#  (('file', '40', 'million'), 2): 1,
#  (('40', 'million', 'returns'), 2): 1,
#  (('million', 'returns', 'filed'), 2): 1,
#  (('returns', 'filed', 'april'), 2): 1,
#  (('``', 'adjustment', 'fall'), 1): 1,
#  (('adjustment', 'fall', 'price'), 1): 1,
#  (('fall', 'price', 'level'), 1): 1,
#  (('price', 'level', 'contrast'), 1): 1,
#  (('level', 'contrast', 'less'), 1): 1,
#  (('contrast', 'less', 'effective'), 1): 1,
#  (('digia', 'said', 'consolidated'), 3): 1,
#  (('said', 'consolidated', 'net'), 3): 1,
#  (('consolidated', 'net', 'sales'), 3): 1,
#  (('net', 'sales', 'january-june'), 3): 1,
#  (('sales', 'january-june', '2010'), 3): 1,
#  (('january-june', '2010', 'eur67'), 3): 1,
#  (('2010', 'eur67', '.8'), 3): 1,
#  (('eur67', '.8', '9.7'), 3): 1,
#  (('.8', '9.7', 'period'), 3): 1,
#  (('9.7', 'period', '2009'), 3): 1,
#  (('period', '2009', 'eur61'), 3): 1,
#  (('2009', 'eur61', '.9'), 3): 1,
#  (('finnish', 'shipping', 'company'), 1): 2,
#  (('shipping', 'company', 'finnlines'), 1): 2,
#  (('company', 'finnlines', 'pretax'), 1): 1,
#  (('finnlines', 'pretax', 'loss'), 1): 1,
#  (('pretax', 'loss', 'totalled'), 1): 2,
#  (('loss', 'totalled', 'eur'), 1): 6,
#  (('totalled', 'eur', '6.5'), 1): 1,
#  (('eur', '6.5', 'mn'), 1): 1,
#  (('6.5', 'mn', 'third'), 1): 1,
#  (('mn', 'third', 'quarter'), 1): 10,
#  (('third', 'quarter', '2009'), 1): 2,
#  (('quarter', '2009', 'compared'), 1): 1,
#  (('2009', 'compared', 'profit'), 1): 1,
#  (('compared', 'profit', 'eur'), 1): 9,
#  (('profit', 'eur', '0.3'), 1): 1,
#  (('eur', '0.3', 'mn'), 1): 4,
#  (('0.3', 'mn', 'third'), 1): 1,
#  (('third', 'quarter', '2008'), 1): 5,
#  (('finnish', 'security', 'privacy'), 3): 2,
#  (('security', 'privacy', 'software'), 3): 2,
#  (('privacy', 'software', 'solutions'), 3): 2,
#  (('software', 'solutions', 'developer'), 3): 2,
#  (('solutions', 'developer', 'stonesoft'), 3): 2,
#  (('developer', 'stonesoft', 'oyj'), 3): 2,
#  (('stonesoft', 'oyj', 'said'), 3): 2,
#  (('oyj', 'said', 'january'), 3): 1,
#  (('said', 'january', '7'), 3): 1,
#  (('january', '7', '2008'), 3): 1,
#  (('7', '2008', 'preliminary'), 3): 1,
#  (('2008', 'preliminary', 'sales'), 3): 1,
#  (('preliminary', 'sales', 'stonegate'), 3): 1,
#  (('sales', 'stonegate', 'products'), 3): 1,
#  (('stonegate', 'products', 'grew'), 3): 1,
#  (('products', 'grew', '59'), 3): 1,
#  (('grew', '59', 'pct'), 3): 1,
#  (('59', 'pct', 'year-on-year'), 3): 1,
#  (('pct', 'year-on-year', '3.6'), 3): 1,
#  (('year-on-year', '3.6', 'mln'), 3): 1,
#  (('3.6', 'mln', 'euro'), 3): 1,
#  (('mln', 'euro', '5.3'), 3): 1,
#  (('euro', '5.3', 'mln'), 3): 1,
#  (('5.3', 'mln', 'fourth'), 3): 1,
#  (('mln', 'fourth', 'quarter'), 3): 1,
#  (('fourth', 'quarter', '2007'), 3): 2,
#  (('finnish', 'cargotec', "'s"), 3): 2,
#  (('cargotec', "'s", 'kalmar'), 3): 2,
#  (("'s", 'kalmar', 'received'), 3): 1,
#  (('kalmar', 'received', 'significant'), 3): 1,
#  (('received', 'significant', 'order'), 3): 1,
#  (('significant', 'order', 'us'), 3): 1,
#  (('order', 'us', 'department'), 3): 1,
#  (('us', 'department', 'defense'), 3): 1,
#  (('new', 'substations', 'support'), 2): 1,
#  (('substations', 'support', 'edge'), 2): 1,
#  (('support', 'edge', 'technology'), 2): 1,
#  ...}

# %%
train['News_3gram'][3207][0]
# Out:
# ('company', 'supposed', 'deliver')

# %%
freqs.keys()
# Out:
# dict_keys([(('company', 'supposed', 'deliver'), 2), (('supposed', 'deliver', 'machinery'), 2), (('deliver', 'machinery', 'veneer'), 2), (('machinery', 'veneer', 'mill'), 2), (('veneer', 'mill', 'tomsk'), 2), (('mill', 'tomsk', 'region'), 2), (('tomsk', 'region', 'russia'), 2), (('unc', 'charlotte', 'would'), 2), (('charlotte', 'would', 'also'), 2), (('would', 'also', 'deploy'), 2), (('also', 'deploy', 'ssh'), 2), (('deploy', 'ssh', 'tectia'), 2), (('ssh', 'tectia', 'connector'), 2), (('tectia', 'connector', 'enable'), 2), (('connector', 'enable', 'secure'), 2), (('enable', 'secure', 'application'), 2), (('secure', 'application', 'connectivity'), 2), (('2009', 'lee', 'man'), 2), (('lee', 'man', 'combined'), 2), (('man', 'combined', 'annual'), 2), (('combined', 'annual', 'production'), 2), (('annual', 'production', 'capacity'), 2), (('production', 'capacity', 'close'), 2), (('capacity', 'close', '4.5'), 2), (('close', '4.5', 'million'), 2), (('4.5', 'million', 'tonnes'), 2), (('million', 'tonnes', 'paper'), 2), (('tonnes', 'paper', '300,000'), 2), (('paper', '300,000', 'tonnes'), 2), (('300,000', 'tonnes', 'pulp'), 2), (('``', "'s", 'high'), 2), (("'s", 'high', 'figure'), 2), (('high', 'figure', 'european'), 2), (('figure', 'european', 'scale'), 2), (('european', 'scale', '``'), 2), (('scale', '``', 'noop'), 2), (('``', 'noop', 'said'), 2), (('noop', 'said', 'recalling'), 2), (('said', 'recalling', 'however'), 2), (('recalling', 'however', 'also'), 2), (('however', 'also', 'includes'), 2), (('also', 'includes', 'beer'), 2), (('includes', 'beer', 'bought'), 2), (('beer', 'bought', 'finnish'), 2), (('bought', 'finnish', 'tourists'), 2), (('finland', 'corresponding', 'service'), 2), (('corresponding', 'service', 'alma'), 2), (('service', 'alma', 'media'), 2), (('alma', 'media', "'s"), 2), (('media', "'s", 'etuovi.com'), 2), (("'s", 'etuovi.com', 'finland'), 2), (('etuovi.com', 'finland', "'s"), 2), (('finland', "'s", 'popular'), 2), (("'s", 'popular', 'best'), 2), (('popular', 'best', 'known'), 2), (('best', 'known', 'nationwide'), 2), (('known', 'nationwide', 'online'), 2), (('nationwide', 'online', 'service'), 2), (('online', 'service', 'home'), 2), (('service', 'home', 'property'), 2), (('home', 'property', 'sales'), 2), (('construction', 'scheduled', 'start'), 2), (('scheduled', 'start', 'april-june'), 2), (('start', 'april-june', '2007'), 2), (('april-june', '2007', 'completed'), 2), (('2007', 'completed', 'early'), 2), (('completed', 'early', '2008'), 2), (('finnish-owned', 'contract', 'manufacturer'), 3), (('contract', 'manufacturer', 'electronics'), 3), (('manufacturer', 'electronics', 'elcoteq'), 3), (('electronics', 'elcoteq', 'hungary'), 3), (('elcoteq', 'hungary', 'kft'), 3), (('hungary', 'kft', 'announced'), 3), (('kft', 'announced', 'plans'), 3), (('announced', 'plans', 'recruit'), 3), (('plans', 'recruit', '650'), 3), (('recruit', '650', 'new'), 3), (('650', 'new', 'staffers'), 3), (('new', 'staffers', 'fulfill'), 3), (('staffers', 'fulfill', 'new'), 3), (('fulfill', 'new', 'orders'), 3), (('new', 'orders', 'p+_cs'), 3), (('orders', 'p+_cs', 'company'), 3), (('p+_cs', 'company', 'two'), 3), (('company', 'two', 'plants'), 3), (('gross', 'area', 'innova'), 2), (('area', 'innova', '2'), 2), (('innova', '2', 'project'), 2), (('2', 'project', '10,000'), 2), (('project', '10,000', 'sq'), 2), (('10,000', 'sq', '107,600'), 2), (('sq', '107,600', 'sq'), 2), (('107,600', 'sq', 'ft'), 2), (('finnish', 'home', 'decoration'), 2), (('home', 'decoration', 'arts'), 2), (('decoration', 'arts', 'crafts'), 2), (('arts', 'crafts', 'retailer'), 2), (('crafts', 'retailer', 'tiimari'), 2), (('retailer', 'tiimari', 'plc'), 2), (('tiimari', 'plc', 'omx'), 2), (('plc', 'omx', 'helsinki'), 2), (('omx', 'helsinki', 'tii1v'), 2), (('helsinki', 'tii1v', 'reported'), 2), (('tii1v', 'reported', 'monday'), 2), (('reported', 'monday', '18'), 2), (('monday', '18', 'august'), 2), (('18', 'august', 'operating'), 2), (('august', 'operating', 'loss'), 2), ...

# %%
def extract_features(tweet):
    x = np.zeros((1, 4)) 
    
    x[0,0] = 1 
    ### START CODE HERE ###
    
    # loop through each word in the list of words
    for word in tweet:
        
        # increment the word count for the negative label 1
        x[0,1] += freqs.get((word,1),0)
        
        # increment the word count for the neutral label 0
        x[0,2] += freqs.get((word,2),0)

        # increment the word count for the positive label 0
        x[0,3] += freqs.get((word,3),0)

    return np.array([x[0,1],x[0,2],x[0,3]])

def token_splitter_pos(a):
    return a[2]

def token_splitter_neg(a):
    return a[0]

def token_splitter_neutral(a):
    return a[1]

# %%
train['News_tokenised'] = train['News_3gram'].apply(extract_features)

train['pos'] = train['News_tokenised'].apply(token_splitter_pos)
train['neg'] = train['News_tokenised'].apply(token_splitter_neg)
train['neu'] = train['News_tokenised'].apply(token_splitter_neutral)

# %%
train
# Out:
#       Sentiment                                      News Headline  \
# 3207          2  The company was supposed to deliver machinery ...
# 1684          2  UNC Charlotte would also deploy SSH Tectia Con...
# 1044          2  In 2009 , Lee & Man had a combined annual prod...
# 4145          2  `` That 's a very high figure on the European ...
# 1538          2  In Finland , the corresponding service is Alma...
# ...         ...                                                ...
# 4772          1  YIT 's Baltic sales in the first three quarter...
# 4478          3  Tieto was looking for an energy solution which...
# 53            3  Seppala 's revenue increased by 0.2 % to EUR10...
# 1796          2  The company has the poser , who wants to impre...
# 1911          2  Sami Sepp+ï¿½nen , CEO for Elisa Eesti , says ...
#
#                                              News_1gram  \
# 3207  [(company,), (supposed,), (deliver,), (machine...
# 1684  [(unc,), (charlotte,), (would,), (also,), (dep...
# 1044  [(2009,), (lee,), (man,), (combined,), (annual...
# 4145  [(``,), ('s,), (high,), (figure,), (european,)...
# 1538  [(finland,), (corresponding,), (service,), (al...
# ...                                                 ...
# 4772  [(yit,), ('s,), (baltic,), (sales,), (first,),...
# 4478  [(tieto,), (looking,), (energy,), (solution,),...
# 53    [(seppala,), ('s,), (revenue,), (increased,), ...
# 1796  [(company,), (poser,), (wants,), (impress,), (...
# 1911  [(sami,), (sepp+ï¿½nen,), (ceo,), (elisa,), (e...
#
#                                              News_2gram  \
# 3207  [(company, supposed), (supposed, deliver), (de...
# 1684  [(unc, charlotte), (charlotte, would), (would,...
# 1044  [(2009, lee), (lee, man), (man, combined), (co...
# 4145  [(``, 's), ('s, high), (high, figure), (figure...
# 1538  [(finland, corresponding), (corresponding, ser...
# ...                                                 ...
# 4772  [(yit, 's), ('s, baltic), (baltic, sales), (sa...
# 4478  [(tieto, looking), (looking, energy), (energy,...
# 53    [(seppala, 's), ('s, revenue), (revenue, incre...
# 1796  [(company, poser), (poser, wants), (wants, imp...
# 1911  [(sami, sepp+ï¿½nen), (sepp+ï¿½nen, ceo), (ceo...
#
#                                              News_3gram    News_tokenised  \
# 3207  [(company, supposed, deliver), (supposed, deli...   [0.0, 7.0, 0.0]
# 1684  [(unc, charlotte, would), (charlotte, would, a...  [0.0, 10.0, 0.0]
# 1044  [(2009, lee, man), (lee, man, combined), (man,...  [0.0, 15.0, 1.0]
# 4145  [(``, 's, high), ('s, high, figure), (high, fi...  [0.0, 15.0, 0.0]
# 1538  [(finland, corresponding, service), (correspon...  [1.0, 23.0, 0.0]
# ...                                                 ...               ...
# 4772  [(yit, 's, baltic), ('s, baltic, sales), (balt...  [16.0, 0.0, 0.0]
# 4478  [(tieto, looking, energy), (looking, energy, s...  [0.0, 0.0, 17.0]
# 53    [(seppala, 's, revenue), ('s, revenue, increas...  [0.0, 0.0, 26.0]
# 1796  [(company, poser, wants), (poser, wants, impre...   [0.0, 5.0, 0.0]
# 1911  [(sami, sepp+ï¿½nen, ceo), (sepp+ï¿½nen, ceo, ...  [0.0, 13.0, 0.0]
#
#        pos   neg   neu
# 3207   0.0   0.0   7.0
# 1684   0.0   0.0  10.0
# 1044   1.0   0.0  15.0
# 4145   0.0   0.0  15.0
# 1538   0.0   1.0  23.0
# ...    ...   ...   ...
# 4772   0.0  16.0   0.0
# 4478  17.0   0.0   0.0
# 53    26.0   0.0   0.0
# 1796   0.0   0.0   5.0
# 1911   0.0   0.0  13.0
#
# [3392 rows x 9 columns]

# %% [markdown]
# Now you can use any classifier to fit [pos, neg, neu] with the target variable and get results
